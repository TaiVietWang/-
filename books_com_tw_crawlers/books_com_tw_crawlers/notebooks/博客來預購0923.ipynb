# %%
#博客來預購
import requests
from bs4 import BeautifulSoup
import csv
import time
from datetime import datetime
import re  # 用於提取 bookID

# 基本的 URL
url = 'https://www.books.com.tw/web/sys_prebooks/books/?o=1&v=1'

# 用來存取數據的列表
books_data = []

# 設定出版日期的篩選條件
date_threshold = datetime.strptime('2024-01-01', '%Y-%m-%d')

# 發送請求並解析 HTML
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# 選擇所有書籍的條目
books = soup.select('div.item')

# 逐一解析每本書籍的資訊
for book in books:
    try:
        # 書名
        title = book.select_one('h4 a').text.strip()

        # 書籍鏈結
        book_link = book.select_one('h4 a')['href'].strip()

        # 提取 bookID (即 URL 中的數字部分)
        book_id = re.search(r'/products/(\d+)', book_link).group(1) if re.search(r'/products/(\d+)', book_link) else 'N/A'

        # 作者及出版日期
        info = book.select_one('li.info').text.strip()
        authors = info.split('，')[0]  # 取出作者
        pub_date_str = info.split('出版日期：')[-1].strip()  # 取出出版日期
        pub_date = datetime.strptime(pub_date_str, '%Y/%m/%d')

        # 如果出版日期在 2024 年 1 月 1 日之後，才抓取數據
        if pub_date > date_threshold:
            # 優惠價和折數
            price_box = book.select_one('ul.price li.set2').text.strip()
            discount = price_box.split('折')[0].strip().replace('優惠價：', '')  # 提取折數
            price = price_box.split('折')[-1].strip().replace('元', '').strip()  # 提取價格

            # 將數據存入列表，包含 bookID
            books_data.append([book_id, title, authors, pub_date_str, f"{discount}折", f"{price}元", book_link])

    except Exception as e:
        print(f"解析書籍時發生錯誤: {e}")

# 休眠一段時間，避免對伺服器發送過多請求
time.sleep(2)

# 生成當天日期並加入到 CSV 文件名中
current_date = datetime.now().strftime('%m%d')
csv_file_path = rf'C:\Users\USER\Desktop\prebooks_data{current_date}.csv'  # 確保替換為正確路徑

# 將結果保存為 CSV 檔案，並新增 bookID 列
with open(csv_file_path, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['bookID', '書名', '作者', '出版日期', '折數', '優惠價', '鏈結'])
    writer.writerows(books_data)

print(f"書籍資訊已保存到 {csv_file_path}")
# Out:
# 書籍資訊已保存到 C:\Users\USER\Desktop\prebooks_data1008.csv

# %%
import csv

# CSV 文件的路徑
csv_file = r"C:\Users\USER\Desktop\prebooks_data1004.csv"

# 打開並讀取 CSV 文件
with open(csv_file, mode='r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    
    # 讀取 CSV 文件的每一行
    for row in csv_reader:
        print(row)
# Out:
# ['bookID', '書名', '作者', '出版日期', '折數', '優惠價', '鏈結']
# ['0011002571', '天堂W Artbook國際中文版【附專用虛寶卡】', 'NCSoft', '2024/12/02', '79折', '1422元', 'https://www.books.com.tw/products/0011002571?loc=P_0002_001']
# ['0011002061', '解讀源氏物語', '林水福', '2024/10/17', '79折', '252元', 'https://www.books.com.tw/products/0011002061?loc=P_0002_002']
# ['0011002057', '源氏物語（六冊不分售）【首刷特贈限量精美桌屏】', '紫式部', '2024/10/17', '79折', '2528元', 'https://www.books.com.tw/products/0011002057?loc=P_0002_003']
# ['0011002054', '源氏物語 （含《解讀源氏物語》，特附典藏精裝書盒、限量編號卡、譯者親筆簽名）【首刷限量精裝噴繪版套書】', '紫式部', '2024/10/17', '79折', '4740元', 'https://www.books.com.tw/products/0011002054?loc=P_0002_004']
# ['0011002378', '絕望者之歌：一個美國白人家族的悲劇與重生【暢銷經典回歸版】', '傑德．凡斯', '2024/10/16', '79折', '331元', 'https://www.books.com.tw/products/0011002378?loc=P_0002_005']
# ['0011000982', '城堡（卡夫卡最繁複神祕的最終代表作‧逝世100週年紀念）', '卡夫卡', '2024/10/10', '79折', '355元', 'https://www.books.com.tw/products/0011000982?loc=P_0002_006']
# ['0011001837', 'Python x AI辦公室作業自動化：Word、Excel、PowerPoint、PDF、CSV、Pandas-多執行緒、排程、藝術二維碼、短網址、電子郵件、爬蟲', '洪錦魁', '2024/10/10', '79折', '695元', 'https://www.books.com.tw/products/0011001837?loc=P_0002_007']
# ['0011001944', '威廉華威克警探 II：迷霧中的祕密', '傑佛瑞．亞契', '2024/10/09', '79折', '395元', 'https://www.books.com.tw/products/0011001944?loc=P_0002_008']
# ['0011001906', '經濟學家看央行與貨幣政策：再談致富的特權', '吳聰敏,陳旭昇,李怡庭,陳南光', '2024/10/08', '79折', '316元', 'https://www.books.com.tw/products/0011001906?loc=P_0002_009']
# ['0010999383', '玲依的世界 ―Re:I― (3)（完）Another World Tour', '時雨沢惠一', '2024/10/07', '79折', '158元', 'https://www.books.com.tw/products/0010999383?loc=P_0002_010']
# ['0010999379', '反派千金與反派少爺若是在相遇後墜入情網 ～與無名精靈締結契約而遭驅逐的千金，今天似乎也在和少爺一較高下～ (2)', '榛名丼', '2024/10/07', '79折', '173元', 'https://www.books.com.tw/products/0010999379?loc=P_0002_011']
# ['0011002145', '梅子老師這一班6：說謊真的好累喔！', '王文華', '2024/10/07', '79折', '237元', 'https://www.books.com.tw/products/0011002145?loc=P_0002_012']
# ['0011002203', '15歲開始的領導養成課：如何讓人願意聽你說話、幫你做事、接受你做出的決定？', '工藤勇一', '2024/10/07', '79折', '276元', 'https://www.books.com.tw/products/0011002203?loc=P_0002_013']
# ['0011002428', '歡迎來我家！動物的奇妙生活3（史前巨獸）：比你還高的奇怪大蝦，跟汽車一樣長的巨大馬陸……從海洋到陸地，40種大開眼界的古老生物', '麥可・巴菲爾,寶拉・波西歐', '2024/10/07', '79折', '276元', 'https://www.books.com.tw/products/0011002428?loc=P_0002_014']
# ['0011001517', '食言犬', '扈嘉仁', '2024/10/07', '79折', '284元', 'https://www.books.com.tw/products/0011001517?loc=P_0002_015']
# ['0011001482', '基恩斯的高附加價值經營──卓越管理篇：日本新首富管理世界頂級企業的原則', '西岡杏', '2024/10/07', '79折', '300元', 'https://www.books.com.tw/products/0011001482?loc=P_0002_016']
# ['0011002218', '願你此生 終抵繁星：那些再愛的再痛的，是伊芙，讓碎片變成星星。【首刷限定 繁星透光書籤2款】', '伊芙（Evelyn）', '2024/10/07', '79折', '300元', 'https://www.books.com.tw/products/0011002218?loc=P_0002_017']
# ['0011002220', '願你此生 終抵繁星：那些再愛的再痛的，是伊芙，讓碎片變成星星。【親筆簽名書+首刷限定 繁星透光書籤2款】', '伊芙（Evelyn）', '2024/10/07', '79折', '300元', 'https://www.books.com.tw/products/0011002220?loc=P_0002_018']
# ['0011002384', '翻篇：翻閱好書，翻越低谷，用42本經典好書的智慧，解答現代人的內心困局', '帆書', '2024/10/07', '79折', '300元', 'https://www.books.com.tw/products/0011002384?loc=P_0002_019']
# ['0011002460', '翻篇：翻閱好書，翻越低谷，用42本經典好書的智慧，解答現代人的內心困局【附首刷限量「文字之光」互動式大透卡】', '帆書', '2024/10/07', '79折', '300元', 'https://www.books.com.tw/products/0011002460?loc=P_0002_020']
# ['0011002207', '小說家與夜晚的界線(首刷限定 印刷留言簽名扉)', '山白朝子', '2024/10/07', '79折', '331元', 'https://www.books.com.tw/products/0011002207?loc=P_0002_021']
# ['0011002379', '光之帝國', '金英夏', '2024/10/07', '79折', '331元', 'https://www.books.com.tw/products/0011002379?loc=P_0002_022']
# ['0011002382', '【讓世界更有趣】戴上哲學的眼鏡看世界：第一本主題式哲學思考書，幫助你看清人生與世界的真相', '小川仁志', '2024/10/07', '79折', '355元', 'https://www.books.com.tw/products/0011002382?loc=P_0002_023']
# ['0011002432', '歡迎來我家！動物的奇妙生活4（恐龍、鳥與哺乳類）：從怪牙、異爪、長翅膀到雙腳站立，60種傳奇動物的生存大對決', '麥可・巴菲爾,寶拉・波西歐', '2024/10/07', '79折', '355元', 'https://www.books.com.tw/products/0011002432?loc=P_0002_024']
# ['0011001489', '人類情感的億萬投射', '卡爾．迪賽羅斯', '2024/10/07', '79折', '379元', 'https://www.books.com.tw/products/0011001489?loc=P_0002_025']
# ['0011002215', '解放時間：打破金錢主宰的時間觀，走向內在幸福的智慧思考', '珍妮．奧德爾\u3000', '2024/10/07', '79折', '410元', 'https://www.books.com.tw/products/0011002215?loc=P_0002_026']
# ['0011001658', '坂本圖書（限量典藏版加贈：「坂本圖書」台灣限定扉頁圖章＋坂本龍一珍貴相片畫卡）', '坂本龍一', '2024/10/07', '79折', '434元', 'https://www.books.com.tw/products/0011001658?loc=P_0002_027']
# ['0011002241', '這樣寫code好不好？辨識、分析、改善，寫出易讀易維護的程式碼', '仙塲大也', '2024/10/07', '79折', '497元', 'https://www.books.com.tw/products/0011002241?loc=P_0002_028']
# ['0011002134', '梅子老師這一班4-6套書【博客來獨家】', '王文華', '2024/10/07', '75折', '675元', 'https://www.books.com.tw/products/0011002134?loc=P_0002_029']
# ['0011000961', '引路人．卷7（突破四千萬瀏覽人次超人氣本土原創漫畫，影視改編進行中！）', '羅寶,桑原', '2024/10/05', '79折', '315元', 'https://www.books.com.tw/products/0011000961?loc=P_0002_030']
# ['0011000962', '引路人．卷8（突破四千萬瀏覽人次超人氣本土原創漫畫，影視改編進行中！）', '羅寶,桑原', '2024/10/05', '79折', '315元', 'https://www.books.com.tw/products/0011000962?loc=P_0002_031']
# ['0011000793', '魔法糖果（暢銷典藏版） （首批加贈-魔法資料夾）', '白希那', '2024/10/05', '79折', '331元', 'https://www.books.com.tw/products/0011000793?loc=P_0002_032']
# ['0011001371', '借物少女5：滿月行動【吉卜力動畫原著小說．暢銷70年全新譯本】', '瑪麗‧諾頓', '2024/10/05', '79折', '331元', 'https://www.books.com.tw/products/0011001371?loc=P_0002_033']
# ['0011000973', '物價跟你想的不一樣：從日常出發，東大教授帶你揭開物價波動的祕密，透過物價看見經濟的真實全貌', '渡邊努', '2024/10/05', '79折', '355元', 'https://www.books.com.tw/products/0011000973?loc=P_0002_034']
# ['0011001825', '夢境時空智慧卡袖珍版（僅含34張夢境時空智慧卡）', '王牧絃Jenny Wang', '2024/10/05', '79折', '387元', 'https://www.books.com.tw/products/0011001825?loc=P_0002_035']
# ['0011000976', '洋菓圖典：130道手繪甜點故事', '長井史枝', '2024/10/05', '79折', '434元', 'https://www.books.com.tw/products/0011000976?loc=P_0002_036']
# ['0011001289', '大樹的祕密', '布萊恩．賽茲尼克', '2024/10/05', '79折', '474元', 'https://www.books.com.tw/products/0011001289?loc=P_0002_037']
# ['0011000959', '引路人卷7+卷8套書（限量作者親簽特典贈品版，突破四千萬瀏覽人次超人氣本土原創漫畫，影視改編進行中！）', '羅寶,桑原', '2024/10/05', '79折', '630元', 'https://www.books.com.tw/products/0011000959?loc=P_0002_038']
# ['0011001528', '幾米年曆2025', '幾米', '2024/10/05', '79折', '790元', 'https://www.books.com.tw/products/0011001528?loc=P_0002_039']
# ['0011001255', '大樹的祕密+雨果的祕密（套書加贈月下的新生帆布袋）', '布萊恩．賽茲尼克', '2024/10/05', '75折', '922元', 'https://www.books.com.tw/products/0011001255?loc=P_0002_040']
# ['0011001824', '夢境時空智慧卡（34張夢境時空智慧卡＋中文解說手冊）', '王牧絃Jenny Wang', '2024/10/05', '79折', '1090元', 'https://www.books.com.tw/products/0011001824?loc=P_0002_041']
# ['0011001370', '借物少女【全系列套書五冊完整上市‧附贈借物少女明信片組‧吉卜力動畫原著小說】', '瑪麗‧諾頓', '2024/10/05', '75折', '1200元', 'https://www.books.com.tw/products/0011001370?loc=P_0002_042']
# ['0011000977', '海洋之戀（上下冊套書，泰國天后Mame同名耽美網劇原著小說，作者手繪印簽限量特典贈品版）', 'Mame', '2024/10/05', '79折', '630元', 'https://www.books.com.tw/products/0011000977?loc=P_0002_043']
